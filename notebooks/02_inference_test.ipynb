# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

# %%
from src.inference import CreditRiskPredictor

predictor = CreditRiskPredictor()

sample_input = {
    "age": 35,
    "gender": "Male",
    "marital_status": "Single",
    "employment_status": "Salaried",
    "number_of_dependants": 1,
    "residence_type": "Owned",
    "years_at_current_address": 5,
    "city": "Bangalore",
    "state": "Karnataka",
    "zipcode": 560001,
    "loan_purpose": "Personal",
    "loan_type": "Unsecured",
    "sanction_amount": 500000,
    "processing_fee": 5000,
    "gst": 900,
    "net_disbursement": 494100,
    "loan_tenure_months": 36,
    "principal_outstanding": 450000,
    "bank_balance_at_application": 150000,
    "number_of_open_accounts": 2,
    "number_of_closed_accounts": 4,
    "enquiry_count": 1,
    "credit_utilization_ratio": 0.35,
    "loan_to_income": 0.25,
    "delinquency_ratio": 0.1,
    "avg_dpd_per_delinquency": 15
}

predictor.predict(sample_input)
# Out:
# {'probability_of_default': np.float64(0.0), 'risk_label': 'Low Risk'}
